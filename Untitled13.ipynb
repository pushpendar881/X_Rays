# %%
# !mkdir -p -/.kaggle
# !cp kaggle.json -/.kaggle/
# Out:
# mkdir: invalid option -- '/'
# Try 'mkdir --help' for more information.
# cp: invalid option -- '/'
# Try 'cp --help' for more information.

# %%
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# Dataset URL: https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia
# License(s): other
# ...
# 100% 2.29G/2.29G [00:13<00:00, 177MB/s]
# 100% 2.29G/2.29G [00:13<00:00, 189MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/chest-xray-pneumonia.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf

# %%
import keras
from tensorflow.keras.utils import image_dataset_from_directory
train_ds=keras.utils.image_dataset_from_directory(
"/content/chest_xray/train",
    labels="inferred",
    color_mode="grayscale",
      batch_size=32,
    label_mode='int',
    image_size=(256, 256),
    shuffle=True
)
# Out:
# Found 5216 files belonging to 2 classes.

# %%
test_ds=keras.utils.image_dataset_from_directory(
"/content/chest_xray/test",
    labels="inferred",
    color_mode="grayscale",
    label_mode='int',
      batch_size=32,
    image_size=(256, 256),
    shuffle=True
)
# Out:
# Found 624 files belonging to 2 classes.

# %%
# # def process(image,label):
# #     image=tf.cast(image/255.,tf.float32)
# #     return image,label
# # train_ds=train_dataset.map(process)
# # test_ds=test_dataset.map(process)

# def process(image ,label):
#     image=tf.cast(image/255.,tf.float32)
#     return image,label
# train_ds=train.map(process)
# test_ds=test.map(process)
def augment_image(image, label):
    # Apply random horizontal and vertical flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)

    # Cast and normalize the image
    image = tf.cast(image / 255.0, tf.float32)

    return image, label

# Augment and preprocess the training dataset
train_ds = train_ds.map(augment_image)
test_ds = test_ds.map(lambda image, label: (tf.cast(image / 255.0, tf.float32), label))

# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout
from keras.callbacks import EarlyStopping

# %%
model=Sequential()

# %%
model.add(Conv2D(32,kernel_size=(3,3),padding='valid',input_shape=(256,256,1),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),padding='valid',strides=2))
model.add(Conv2D(64,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),padding='valid',strides=2))
model.add(Conv2D(128,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),padding='valid',strides=2))
model.add(Flatten())

model.add(Dense(128,activation='relu'))
# model.add(Dropout(0.2))
model.add(Dense(64,activation='relu'))
# model.add(Dropout(0.2))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 254, 254, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
model.compile(optimizer='adam',metrics=['accuracy'],loss='binary_crossentropy')

# %%
history=model.fit(train_ds,epochs=5,validation_data=test_ds,callbacks=EarlyStopping())
# Out:
# Epoch 1/5
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 258ms/step - accuracy: 0.8566 - loss: 2.1919 - val_accuracy: 0.6250 - val_loss: 64.5310
# Epoch 2/5
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 68s 229ms/step - accuracy: 0.9452 - loss: 0.2846 - val_accuracy: 0.6250 - val_loss: 38.7113
# Epoch 3/5
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.9541 - loss: 0.1690 - val_accuracy: 0.6250 - val_loss: 20.5332
# Epoch 4/5
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 42s 222ms/step - accuracy: 0.9543 - loss: 0.1573 - val_accuracy: 0.6891 - val_loss: 2.0645
# Epoch 5/5
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 40s 218ms/step - accuracy: 0.9521 - loss: 0.2094 - val_accuracy: 0.7772 - val_loss: 0.9216

# %%
import pandas as pd
pd.DataFrame(history.history).plot(figsize=(10,7))
# Out:
# <Axes: >

# %%
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  """
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
plot_loss_curves(history)

# %%
import pickle
pickle.dump(model,open('regmodel1.pkl','wb'))

# %%
import cv2
test_img=cv2.imread('/content/NORMAL2-IM-1427-0001.jpeg')
plt.imshow(test_img)

# %%
test_img = cv2.imread('/content/NORMAL2-IM-1427-0001.jpeg', cv2.IMREAD_GRAYSCALE)  # Load as grayscale
test_img = cv2.resize(test_img, (256, 256))  # Resize to match input shape

plt.imshow(test_img, cmap='gray')  # Display the test image

# Preprocess the image for prediction
test_img = test_img / 255.0  # Normalize the image
test_img = test_img.reshape(1, 256, 256, 1)  # Reshape to include batch size and channel

# Predict using the trained model
prediction = model.predict(test_img)
print(f"Prediction: {prediction[0][0]}")

# Interpret the prediction
if prediction[0][0] > 0.5:
    print("Prediction: Pneumonia")
else:
    print("Prediction: Normal")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Prediction: 0.037189505994319916
# Prediction: Normal
